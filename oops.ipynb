# %%
##initiate a class
# Out:
# The kernel failed to start as the Python Environment 'venv (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
1+1
# Out:
# 2

# %%
class employee:
    def __init__(self):
        self.id=123
        self.salary=50000
        self.designation='SDE'
